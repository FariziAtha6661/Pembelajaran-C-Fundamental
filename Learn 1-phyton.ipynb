# %% [markdown]
# <a href="https://colab.research.google.com/github/FariziAtha6661/Pembelajaran-C-Fundamental/blob/main/Learn%201-phyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Materi pertama pembelajaran python

# %%
b=30
b=31
c=A+B
print (c)
# Out:
# 61
